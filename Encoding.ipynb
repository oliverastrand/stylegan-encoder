# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls gdrive/My\ Drive/Colabs
# Out:
# aligned_images	  generated_images			 raw_images
# align_images.py   generate_figures.py			 README.md
# cache		  latent_representations		 requirements.txt
# config.py	  Learn_direction_in_latent_space.ipynb  run_metrics.py
# dataset_tool.py   LICENSE.txt				 teaser.png
# dnnlib		  logs					 Testing.ipynb
# encode_images.py  metrics				 training
# encoder		  Play_with_latent_directions.ipynb	 train.py
# Encoding.ipynb	  pretrained_example.py
# ffhq_dataset	  __pycache__

# %%
# !pip install tensorflow-gpu==1.14
# Out:
# ...
#      |████████████████████████████████| 377.0MB 66kB/s
# ...
#      |████████████████████████████████| 491kB 35.5MB/s
# ...
#      |████████████████████████████████| 3.2MB 23.6MB/s
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 1.14.0 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.14.0 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
# ...

# %%
import tensorflow

# %%
tensorflow.__version__

# %%
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

# %%
get_available_gpus()
# Out:
# ['/device:GPU:0']

# %%
# %run /content/gdrive/My\ Drive/Colabs/encode_images.py /content/gdrive/My\ Drive/Colabs/aligned_images/ /content/gdrive/My\ Drive/Colabs/generated_images/ /content/gdrive/My\ Drive/Colabs/latent_representations/
# Out:
# WARNING:tensorflow:From /content/gdrive/My Drive/Colabs/dnnlib/tflib/tfutil.py:34: The name tf.Dimension is deprecated. Please use tf.compat.v1.Dimension instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colabs/dnnlib/tflib/tfutil.py:74: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colabs/dnnlib/tflib/tfutil.py:128: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colabs/dnnlib/tflib/tfutil.py:97: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Colabs/dnnlib/tflib/tfutil.py:109: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# Using TensorFlow backend.
# ...

# %%
tensorflow.__version__
# Out:
# '1.14.0'

# %%
# !pwd
# Out:
# /content
